# %%
# variables for easy file manipulation! 
dataset_chosen = "" # "dermnet, ham10000, Atlas_ISIC"

# %%
# # Swap kernels to Python 3.10
# %pip install ipykernel
# %pip install ipywidgets
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# Requirement already satisfied: ipykernel in /data/team01/ds340w/lib/python3.12/site-packages (7.1.0)
# Requirement already satisfied: comm>=0.1.1 in /data/team01/ds340w/lib/python3.12/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /data/team01/ds340w/lib/python3.12/site-packages (from ipykernel) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /data/team01/ds340w/lib/python3.12/site-packages (from ipykernel) (9.9.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /data/team01/ds340w/lib/python3.12/site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /data/team01/ds340w/lib/python3.12/site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /data/team01/ds340w/lib/python3.12/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /data/team01/ds340w/lib/python3.12/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in /data/team01/ds340w/lib/python3.12/site-packages (from ipykernel) (26.0)
# Requirement already satisfied: psutil>=5.7 in /data/team01/ds340w/lib/python3.12/site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /data/team01/ds340w/lib/python3.12/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /data/team01/ds340w/lib/python3.12/site-packages (from ipykernel) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in /data/team01/ds340w/lib/python3.12/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator>=4.3.2 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /data/team01/ds340w/lib/python3.12/site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /data/team01/ds340w/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /data/team01/ds340w/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /data/team01/ds340w/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /data/team01/ds340w/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.5.3)
# Requirement already satisfied: six>=1.5 in /data/team01/ds340w/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /data/team01/ds340w/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /data/team01/ds340w/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in /data/team01/ds340w/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipywidgets in /data/team01/ds340w/lib/python3.12/site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in /data/team01/ds340w/lib/python3.12/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /data/team01/ds340w/lib/python3.12/site-packages (from ipywidgets) (9.9.0)
# Requirement already satisfied: traitlets>=4.3.1 in /data/team01/ds340w/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /data/team01/ds340w/lib/python3.12/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /data/team01/ds340w/lib/python3.12/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: decorator>=4.3.2 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /data/team01/ds340w/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /data/team01/ds340w/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /data/team01/ds340w/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /data/team01/ds340w/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.5.3)
# Requirement already satisfied: executing>=1.2.0 in /data/team01/ds340w/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /data/team01/ds340w/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in /data/team01/ds340w/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# batch size for training and evaluation
batch_size = 32

# DINOV2
model_checkpoint = "facebook/dinov2-base" # pre-trained model from which to fine-tune

#

# %%
# %pip install evaluate datasets scikit-learn
# %pip install -U accelerate
# %pip install -U transformers
# %pip install pillow
# Out:
# Requirement already satisfied: evaluate in /data/team01/ds340w/lib/python3.12/site-packages (0.4.6)
# Requirement already satisfied: datasets in /data/team01/ds340w/lib/python3.12/site-packages (4.8.4)
# Requirement already satisfied: scikit-learn in /data/team01/ds340w/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.17 in /data/team01/ds340w/lib/python3.12/site-packages (from evaluate) (2.4.4)
# Requirement already satisfied: dill in /data/team01/ds340w/lib/python3.12/site-packages (from evaluate) (0.4.0)
# Requirement already satisfied: pandas in /data/team01/ds340w/lib/python3.12/site-packages (from evaluate) (3.0.0)
# Requirement already satisfied: requests>=2.19.0 in /data/team01/ds340w/lib/python3.12/site-packages (from evaluate) (2.32.5)
# Requirement already satisfied: tqdm>=4.62.1 in /data/team01/ds340w/lib/python3.12/site-packages (from evaluate) (4.67.2)
# Requirement already satisfied: xxhash in /data/team01/ds340w/lib/python3.12/site-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /data/team01/ds340w/lib/python3.12/site-packages (from evaluate) (0.70.18)
# Requirement already satisfied: fsspec>=2021.05.0 in /data/team01/ds340w/lib/python3.12/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /data/team01/ds340w/lib/python3.12/site-packages (from evaluate) (1.10.1)
# Requirement already satisfied: packaging in /data/team01/ds340w/lib/python3.12/site-packages (from evaluate) (26.0)
# Requirement already satisfied: filelock in /data/team01/ds340w/lib/python3.12/site-packages (from datasets) (3.20.3)
# Requirement already satisfied: pyarrow>=21.0.0 in /data/team01/ds340w/lib/python3.12/site-packages (from datasets) (23.0.0)
# Requirement already satisfied: httpx<1.0.0 in /data/team01/ds340w/lib/python3.12/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /data/team01/ds340w/lib/python3.12/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: scipy>=1.10.0 in /data/team01/ds340w/lib/python3.12/site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /data/team01/ds340w/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /data/team01/ds340w/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /data/team01/ds340w/lib/python3.12/site-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.3)
# Requirement already satisfied: anyio in /data/team01/ds340w/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in /data/team01/ds340w/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /data/team01/ds340w/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /data/team01/ds340w/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /data/team01/ds340w/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface-hub>=0.7.0->evaluate) (1.4.3)
# Requirement already satisfied: typer in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface-hub>=0.7.0->evaluate) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /data/team01/ds340w/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /data/team01/ds340w/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (2.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /data/team01/ds340w/lib/python3.12/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /data/team01/ds340w/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /data/team01/ds340w/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /data/team01/ds340w/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /data/team01/ds340w/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /data/team01/ds340w/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /data/team01/ds340w/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /data/team01/ds340w/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: six>=1.5 in /data/team01/ds340w/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in /data/team01/ds340w/lib/python3.12/site-packages (from typer->huggingface-hub>=0.7.0->evaluate) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /data/team01/ds340w/lib/python3.12/site-packages (from typer->huggingface-hub>=0.7.0->evaluate) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /data/team01/ds340w/lib/python3.12/site-packages (from typer->huggingface-hub>=0.7.0->evaluate) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /data/team01/ds340w/lib/python3.12/site-packages (from typer->huggingface-hub>=0.7.0->evaluate) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /data/team01/ds340w/lib/python3.12/site-packages (from rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /data/team01/ds340w/lib/python3.12/site-packages (from rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /data/team01/ds340w/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: accelerate in /data/team01/ds340w/lib/python3.12/site-packages (1.13.0)
# Requirement already satisfied: numpy>=1.17 in /data/team01/ds340w/lib/python3.12/site-packages (from accelerate) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /data/team01/ds340w/lib/python3.12/site-packages (from accelerate) (26.0)
# Requirement already satisfied: psutil in /data/team01/ds340w/lib/python3.12/site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: pyyaml in /data/team01/ds340w/lib/python3.12/site-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /data/team01/ds340w/lib/python3.12/site-packages (from accelerate) (2.10.0)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /data/team01/ds340w/lib/python3.12/site-packages (from accelerate) (1.10.1)
# Requirement already satisfied: safetensors>=0.4.3 in /data/team01/ds340w/lib/python3.12/site-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface_hub>=0.21.0->accelerate) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface_hub>=0.21.0->accelerate) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface_hub>=0.21.0->accelerate) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface_hub>=0.21.0->accelerate) (0.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.2)
# Requirement already satisfied: typer in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface_hub>=0.21.0->accelerate) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: setuptools in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /data/team01/ds340w/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /data/team01/ds340w/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch>=2.0.0->accelerate) (1.3.3)
# Requirement already satisfied: anyio in /data/team01/ds340w/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (4.12.1)
# Requirement already satisfied: certifi in /data/team01/ds340w/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /data/team01/ds340w/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (1.0.9)
# Requirement already satisfied: idna in /data/team01/ds340w/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: h11>=0.16 in /data/team01/ds340w/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /data/team01/ds340w/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /data/team01/ds340w/lib/python3.12/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /data/team01/ds340w/lib/python3.12/site-packages (from typer->huggingface_hub>=0.21.0->accelerate) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /data/team01/ds340w/lib/python3.12/site-packages (from typer->huggingface_hub>=0.21.0->accelerate) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /data/team01/ds340w/lib/python3.12/site-packages (from typer->huggingface_hub>=0.21.0->accelerate) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /data/team01/ds340w/lib/python3.12/site-packages (from typer->huggingface_hub>=0.21.0->accelerate) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /data/team01/ds340w/lib/python3.12/site-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /data/team01/ds340w/lib/python3.12/site-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /data/team01/ds340w/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: transformers in /data/team01/ds340w/lib/python3.12/site-packages (5.5.4)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /data/team01/ds340w/lib/python3.12/site-packages (from transformers) (1.10.1)
# Requirement already satisfied: numpy>=1.17 in /data/team01/ds340w/lib/python3.12/site-packages (from transformers) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /data/team01/ds340w/lib/python3.12/site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /data/team01/ds340w/lib/python3.12/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /data/team01/ds340w/lib/python3.12/site-packages (from transformers) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /data/team01/ds340w/lib/python3.12/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /data/team01/ds340w/lib/python3.12/site-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /data/team01/ds340w/lib/python3.12/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /data/team01/ds340w/lib/python3.12/site-packages (from transformers) (4.67.2)
# Requirement already satisfied: filelock>=3.10.0 in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /data/team01/ds340w/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: click>=8.2.1 in /data/team01/ds340w/lib/python3.12/site-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /data/team01/ds340w/lib/python3.12/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /data/team01/ds340w/lib/python3.12/site-packages (from typer->transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /data/team01/ds340w/lib/python3.12/site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /data/team01/ds340w/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /data/team01/ds340w/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /data/team01/ds340w/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /data/team01/ds340w/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /data/team01/ds340w/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /data/team01/ds340w/lib/python3.12/site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /data/team01/ds340w/lib/python3.12/site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /data/team01/ds340w/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pillow in /data/team01/ds340w/lib/python3.12/site-packages (12.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# IDK
# %%capture
# %sudo apt -qq install git-lfs
# %git config --global credential.helper store

# %%
import torch
import gc
import os

# 
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def clear_gpu():
    torch.cuda.empty_cache()
    gc.collect()

clear_gpu()

# %%
import sys
from datasets import load_dataset
dataset = load_dataset("imagefolder", data_dir="/data/team01/ds340w/datasets/dermnet_split")
# Out:
# Resolving data files:   0%|          | 0/13502 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/1929 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/3858 [00:00<?, ?it/s]

# %%
import evaluate

metric = evaluate.load("accuracy")
dataset
dataset["train"].features
# Out:
# {'image': Image(mode=None, decode=True),
#  'label': ClassLabel(names=['Acne and Rosacea Photos', 'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions', 'Atopic Dermatitis Photos', 'Bullous Disease Photos', 'Cellulitis Impetigo and other Bacterial Infections', 'Eczema Photos', 'Exanthems and Drug Eruptions', 'Hair Loss Photos Alopecia and other Hair Diseases', 'Herpes HPV and other STDs Photos', 'Light Diseases and Disorders of Pigmentation', 'Lupus and other Connective Tissue diseases', 'Melanoma Skin Cancer Nevi and Moles', 'Nail Fungus and other Nail Disease', 'Poison Ivy Photos and other Contact Dermatitis', 'Psoriasis pictures Lichen Planus and related diseases', 'Scabies Lyme Disease and other Infestations and Bites', 'Seborrheic Keratoses and other Benign Tumors', 'Systemic Disease', 'Tinea Ringworm Candidiasis and other Fungal Infections', 'Urticaria Hives', 'Vascular Tumors', 'Vasculitis Photos', 'Warts Molluscum and other Viral Infections'])}

# %%
example = dataset["train"][10]
example
example['image']
example['label']
dataset["train"].features["label"]
# Out:
# ClassLabel(names=['Acne and Rosacea Photos', 'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions', 'Atopic Dermatitis Photos', 'Bullous Disease Photos', 'Cellulitis Impetigo and other Bacterial Infections', 'Eczema Photos', 'Exanthems and Drug Eruptions', 'Hair Loss Photos Alopecia and other Hair Diseases', 'Herpes HPV and other STDs Photos', 'Light Diseases and Disorders of Pigmentation', 'Lupus and other Connective Tissue diseases', 'Melanoma Skin Cancer Nevi and Moles', 'Nail Fungus and other Nail Disease', 'Poison Ivy Photos and other Contact Dermatitis', 'Psoriasis pictures Lichen Planus and related diseases', 'Scabies Lyme Disease and other Infestations and Bites', 'Seborrheic Keratoses and other Benign Tumors', 'Systemic Disease', 'Tinea Ringworm Candidiasis and other Fungal Infections', 'Urticaria Hives', 'Vascular Tumors', 'Vasculitis Photos', 'Warts Molluscum and other Viral Infections'])

# %%
labels = dataset["train"].features["label"].names
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = i
    id2label[i] = label

id2label[2]
# Out:
# 'Atopic Dermatitis Photos'

# %%
from transformers import AutoImageProcessor

image_processor = AutoImageProcessor.from_pretrained(model_checkpoint)
image_processor

# %%
from torchvision.transforms import (
    CenterCrop,
    Compose,
    Normalize,
    RandomHorizontalFlip,
    RandomResizedCrop,
    Resize,
    ToTensor,
)

normalize = Normalize(mean=image_processor.image_mean, std=image_processor.image_std)
if "height" in image_processor.size:
    size = (image_processor.size["height"], image_processor.size["width"])
    crop_size = size
    max_size = None
elif "shortest_edge" in image_processor.size:
    size = image_processor.size["shortest_edge"]
    crop_size = (size, size)
    max_size = image_processor.size.get("longest_edge")

train_transforms = Compose(
        [
            RandomResizedCrop(crop_size),
            RandomHorizontalFlip(),
            ToTensor(),
            normalize,
        ]
    )

val_transforms = Compose(
        [
            Resize(size),
            CenterCrop(crop_size),
            ToTensor(),
            normalize,
        ]
    )

def preprocess_train(example_batch):
    """Apply train_transforms across a batch."""
    example_batch["pixel_values"] = [
        train_transforms(image.convert("RGB")) for image in example_batch["image"]
    ]
    return example_batch

def preprocess_val(example_batch):
    """Apply val_transforms across a batch."""
    example_batch["pixel_values"] = [val_transforms(image.convert("RGB")) for image in example_batch["image"]]
    return example_batch

# %%
# split up training into training + validation
train_ds = dataset["train"]
val_ds = dataset["test"] # Technically the "test" split

train_ds.set_transform(preprocess_train)
val_ds.set_transform(preprocess_val)

# train_ds[0]

# %%
from transformers import AutoModelForImageClassification, TrainingArguments, Trainer

model = AutoModelForImageClassification.from_pretrained(
    model_checkpoint,
    label2id=label2id,
    id2label=id2label,
    ignore_mismatched_sizes = True, # provide this in case you're planning to fine-tune an already fine-tuned checkpoint
)

import accelerate
import transformers

transformers.__version__, accelerate.__version__
# Out:
# Loading weights:   0%|          | 0/223 [00:00<?, ?it/s]
# Dinov2ForImageClassification LOAD REPORT from: facebook/dinov2-base
# Key               | Status  |
# ------------------+---------+-
# classifier.bias   | MISSING |
# classifier.weight | MISSING |
#
# Notes:
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ('5.5.4', '1.13.0')

# %%
model_name = model_checkpoint.split("/")[-1]

args = TrainingArguments(
    f"dinov2-base-rawdata-finetuned-SkinDisease",
    remove_unused_columns=False,
    eval_strategy = "epoch",
    save_strategy = "epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=batch_size,
    gradient_accumulation_steps=4,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=10,
    warmup_ratio=0.1,
    logging_steps=10,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    push_to_hub=True,
)
# Out:
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.

# %%
import numpy as np

# the compute_metrics function takes a Named Tuple as input:
# predictions, which are the logits of the model as Numpy arrays,
# and label_ids, which are the ground-truth labels as Numpy arrays.
def compute_metrics(eval_pred):
    """Computes accuracy on a batch of predictions"""
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return metric.compute(predictions=predictions, references=eval_pred.label_ids)

import torch

def collate_fn(examples):
    pixel_values = torch.stack([example["pixel_values"] for example in examples])
    labels = torch.tensor([example["label"] for example in examples])
    return {"pixel_values": pixel_values, "labels": labels}

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    processing_class=image_processor,
    compute_metrics=compute_metrics,
    data_collator=collate_fn,
)

train_results = trainer.train()
# rest is optional but nice to have
trainer.save_model()
trainer.log_metrics("train", train_results.metrics)
trainer.save_metrics("train", train_results.metrics)
trainer.save_state()
# Out:
#     <div>
#
#       <progress value='743' max='1060' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 743/1060 23:56 < 10:14, 0.52 it/s, Epoch 7/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.295892</td>
#       <td>2.053152</td>
#       <td>0.388802</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.870643</td>
#       <td>1.668162</td>
#       <td>0.496371</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.486616</td>
#       <td>1.405646</td>
#       <td>0.573354</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.335147</td>
#       <td>1.306142</td>
#       <td>0.607569</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.022932</td>
#       <td>1.194413</td>
#       <td>0.649300</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.814984</td>
#       <td>1.088667</td>
#       <td>0.680404</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='17' max='121' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 17/121 00:04 < 00:27, 3.85 it/s]
#     </div>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
metrics = trainer.evaluate()
# some nice to haves:
trainer.log_metrics("eval", metrics)
trainer.save_metrics("eval", metrics)

# %%
from transformers import AutoModelForImageClassification, AutoImageProcessor
from sklearn.metrics import accuracy_score
import torch

# Load the pre-trained model and image processor
# repo_name = "Jayanth2002/dinov2-base-rawdata-finetuned-SkinDisease"
# image_processor = AutoImageProcessor.from_pretrained(repo_name)
# model = AutoModelForImageClassification.from_pretrained(repo_name)

# Load and preprocess the test images
test_data_dir = "/data/team01/ds340w/datasets/ham10000_split/test"  # Path to the test data directory
test_images = load_dataset("imagefolder", data_dir=test_data_dir)

# Preprocess the test images
test_images.set_transform(preprocess_val)  # Use the same validation transforms

# Create a test dataset
test_ds = test_images["train"]  # Use the "train" split for the test data

# %%
### ERROR: Model is living on GPU (CUDA), but image data is still on CPU.

# 1. Determine the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval() # Good practice: set model to evaluation mode
print(f"Using device: {device}")

# Initialize lists to store predicted and actual labels
predicted_labels = []
actual_labels = []

# Iterate through the test dataset and make predictions
for example in test_ds:
    image = example["image"]
    
    # 2. Process the image (This creates tensors on the CPU by default)
    encoding = image_processor(image.convert("RGB"), return_tensors="pt")

    # 3. MOVE THE IMAGES TO GPU
    # We loop through the dictionary and move each tensor to the GPU
    encoding = {k: v.to(device) for k, v in encoding.items()}

    with torch.no_grad():
        # 4. Now both the model and the encoding are on the same device
        outputs = model(**encoding)
        logits = outputs.logits

    # 5. Bring the result back to CPU to extract the number
    predicted_class_idx = logits.argmax(-1).item()
    predicted_labels.append(predicted_class_idx)
    actual_labels.append(example["label"])

# Calculate accuracy
accuracy = accuracy_score(actual_labels, predicted_labels)
print(f"Test Accuracy: {accuracy:.4f}")
